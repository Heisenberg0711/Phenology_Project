# %%
import glob, os
import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio
import rasterio.mask
import skopt
from scipy import optimize
from matplotlib import pyplot as plt
from rasterio import Affine
from rasterio.warp import reproject, Resampling

# %%
#Process the county sowing dataset
current_year = 2008
current_year_str = str(current_year)
os.chdir('/home/heisenberg/my_repo/Data')

df = pd.read_csv('maize.alldat.nolatlon.csv')
IL = (df['state']=='IL')&(df['YEAR']==current_year)
IL_county = df[IL]
col_list = ['FIPS','sday']
IL_county = IL_county[col_list]
IL_county = IL_county.groupby(['FIPS']).mean()
sow_date = list(IL_county['sday'])
del df

#Get all county FIPS in Illinois
county_FIPS = IL_county.index.values
county_FIPS = county_FIPS.tolist()
county_FIPS = list(map(str,county_FIPS))

# %%
#Get all counties in IL in the shape file
os.chdir('/home/heisenberg/my_repo/Data/County_Shape')
county_shape = gpd.read_file('CoUS_GCS12.shp')
county_shape = county_shape[county_shape['atlas_stco'].isin(county_FIPS)]
cols = ['atlas_stco','geometry']
county_shape = county_shape[cols]

# %%
#Read CDL data and change the CDL data to corn/non-corn
os.chdir('/home/heisenberg/my_repo/Data/CDL')
cdl_name = 'CDL_' + current_year_str + '.tif'
cdl = rasterio.open(cdl_name)
cdl_data = cdl.read(1)
cdl_data[cdl_data != 1] = 0

#Read state shape file
os.chdir('/home/heisenberg/my_repo/Data')
state = gpd.read_file('cb_2017_us_state_500k/')

# %%
def mask_by_county(county_shape, corn, i):
    img_clip, trans = rasterio.mask.mask(corn, [county_shape.iloc[i].geometry], crop=True)
    img_clip = img_clip.astype('float32')
    img_clip[img_clip == 0] = np.nan
    index = np.nanmean(img_clip)
    return (img_clip[0,:,:],index)

# %%
#Function that returns GCVI index for each county for each GCVI GeoTIFF
def calculate_GCVI(filename, state, cdl, cdl_data, county_shape):
    gcvi = rasterio.open(filename)
    state.crs = gcvi.crs

    img_clip, trans = rasterio.mask.mask(gcvi, [state.iloc[1].geometry], crop=True)
    img_clip = img_clip.astype('float32')
    img_clip[img_clip == 0] = np.nan
    #plt.imshow(img_clip[0,:,:],vmin=0, vmax=800, cmap='Spectral')

    #Project the CDL to GCVI size
    newarr = np.empty(shape=(img_clip.shape[0],
                             img_clip.shape[1],img_clip.shape[2]))
    reproject(
        cdl_data, newarr,
        src_transform = cdl.transform,
        dst_transform = gcvi.transform,
        src_crs = cdl.crs,
        dst_crs = gcvi.crs,
        resampling = Resampling.average)

    #Bigger than 0.5 means there is corn, while smaller than 0.5 means no corn
    is_corn = newarr >= 0.5
    corn_field = is_corn.astype(int)
    corn_field = corn_field.astype(np.float64)

    #Finally mask the corn/non-corn matrix with gcvi to get gcvi indexes
    gcvi_corn = np.multiply(img_clip, corn_field)
    #plt.imshow(gcvi_corn.squeeze())

    #Re-Write the projected GCVI to a new tif file
    os.chdir('/home/heisenberg/my_repo/Data/Output/')
    new_dataset = rasterio.open('filter1.tif', 'w', driver='GTiff',
                                height = corn_field.shape[1], width = corn_field.shape[2],
                                count = 1, dtype = corn_field.dtype,
                                crs = gcvi.crs,
                                transform = gcvi.transform)

    new_dataset.write(gcvi_corn.squeeze(),1)
    new_dataset.close()

    #Change the projection of shape file to cdl file.
    county_shape.crs = cdl.crs
    num_of_county = len(county_shape.index)


    #Read saved gcvi_corn raster file for masking
    test = rasterio.open('filter1.tif')
    #corn_by_county = {}
    index_by_county = {}

    for county in range(num_of_county):
        result = mask_by_county(county_shape,test,county)
        #corn_by_county[county] = result[0]
        index_by_county[county] = result[1]
    os.remove('filter1.tif')
    return index_by_county

# %%
#Iterate every tif file in a specific year's gcvi directory.
gcvi_directory = os.fsdecode('/home/heisenberg/my_repo/Data/GCVI/'+ current_year_str)
os.chdir(gcvi_directory)
index = 0
All_GCVI = {}

for infile in sorted(glob.glob(os.path.join('*.tif'))):
    os.chdir(gcvi_directory)
    All_GCVI[index] = calculate_GCVI(infile, state, cdl, cdl_data, county_shape)
    index += 1
    print(infile)
    print("image"+str(index)+" completed \n")
    
print("There are a total of " + str(len(All_GCVI)) + "gcvi images")
# Out:
# GCVI_filled_2008001.tif
# image1 completed
#
# GCVI_filled_2008002.tif
# image2 completed
#
# GCVI_filled_2008003.tif
# image3 completed
#
# GCVI_filled_2008004.tif
# image4 completed
#
# GCVI_filled_2008005.tif
# image5 completed
#
# GCVI_filled_2008006.tif
# image6 completed
#
# GCVI_filled_2008007.tif
# image7 completed
#
# GCVI_filled_2008008.tif
# image8 completed
#
# GCVI_filled_2008009.tif
# image9 completed
#
# GCVI_filled_2008010.tif
# image10 completed
#
# GCVI_filled_2008011.tif
# image11 completed
#
# GCVI_filled_2008012.tif
# image12 completed
#
# GCVI_filled_2008013.tif
# image13 completed
#
# GCVI_filled_2008014.tif
# image14 completed
#
# GCVI_filled_2008015.tif
# image15 completed
#
# GCVI_filled_2008016.tif
# image16 completed
#
# GCVI_filled_2008017.tif
# image17 completed
#
# GCVI_filled_2008018.tif
# image18 completed
#
# GCVI_filled_2008019.tif
# image19 completed
#
# GCVI_filled_2008020.tif
# image20 completed
#
# GCVI_filled_2008021.tif
# image21 completed
#
# GCVI_filled_2008022.tif
# image22 completed
#
# GCVI_filled_2008023.tif
# image23 completed
#
# GCVI_filled_2008024.tif
# image24 completed
#
# GCVI_filled_2008025.tif
# image25 completed
#
# GCVI_filled_2008026.tif
# image26 completed
#
# GCVI_filled_2008027.tif
# image27 completed
#
# GCVI_filled_2008028.tif
# image28 completed
#
# GCVI_filled_2008029.tif
# image29 completed
#
# GCVI_filled_2008030.tif
# image30 completed
#
# GCVI_filled_2008031.tif
# image31 completed
#
# GCVI_filled_2008032.tif
# image32 completed
#
# GCVI_filled_2008033.tif
# image33 completed
#
# GCVI_filled_2008034.tif
# image34 completed
#
# GCVI_filled_2008035.tif
# image35 completed
#
# GCVI_filled_2008036.tif
# image36 completed
#
# GCVI_filled_2008037.tif
# image37 completed
#
# GCVI_filled_2008038.tif
# image38 completed
#
# GCVI_filled_2008039.tif
# image39 completed
#
# GCVI_filled_2008040.tif
# image40 completed
#
# GCVI_filled_2008041.tif
# image41 completed
#
# GCVI_filled_2008042.tif
# image42 completed
#
# GCVI_filled_2008043.tif
# image43 completed
#
# GCVI_filled_2008044.tif
# image44 completed
#
# GCVI_filled_2008045.tif
# image45 completed
#
# GCVI_filled_2008046.tif
# image46 completed
#
# GCVI_filled_2008047.tif
# image47 completed
#
# GCVI_filled_2008048.tif
# image48 completed
#
# GCVI_filled_2008049.tif
# image49 completed
#
# GCVI_filled_2008050.tif
# image50 completed
#
# GCVI_filled_2008051.tif
# image51 completed
#
# GCVI_filled_2008052.tif
# image52 completed
#
# GCVI_filled_2008053.tif
# image53 completed
#
# GCVI_filled_2008054.tif
# image54 completed
#
# GCVI_filled_2008055.tif
# image55 completed
#
# GCVI_filled_2008056.tif
# image56 completed
#
# GCVI_filled_2008057.tif
# image57 completed
#
# GCVI_filled_2008058.tif
# image58 completed
#
# GCVI_filled_2008059.tif
# image59 completed
#
# GCVI_filled_2008060.tif
# image60 completed
#
# GCVI_filled_2008061.tif
# image61 completed
#
# GCVI_filled_2008062.tif
# image62 completed
#
# GCVI_filled_2008063.tif
# image63 completed
#
# GCVI_filled_2008064.tif
# image64 completed
#
# GCVI_filled_2008065.tif
# image65 completed
#
# GCVI_filled_2008066.tif
# image66 completed
#
# GCVI_filled_2008067.tif
# image67 completed
#
# GCVI_filled_2008068.tif
# image68 completed
#
# GCVI_filled_2008069.tif
# image69 completed
#
# GCVI_filled_2008070.tif
# image70 completed
#
# GCVI_filled_2008071.tif
# image71 completed
#
# GCVI_filled_2008072.tif
# image72 completed
#
# GCVI_filled_2008073.tif
# image73 completed
#
# GCVI_filled_2008074.tif
# image74 completed
#
# GCVI_filled_2008075.tif
# image75 completed
#
# GCVI_filled_2008076.tif
# image76 completed
#
# GCVI_filled_2008077.tif
# image77 completed
#
# GCVI_filled_2008078.tif
# image78 completed
#
# GCVI_filled_2008079.tif
# image79 completed
#
# GCVI_filled_2008080.tif
# image80 completed
#
# GCVI_filled_2008081.tif
# image81 completed
#
# GCVI_filled_2008082.tif
# image82 completed
#
# GCVI_filled_2008083.tif
# image83 completed
#
# GCVI_filled_2008084.tif
# image84 completed
#
# GCVI_filled_2008085.tif
# image85 completed
#
# GCVI_filled_2008086.tif
# image86 completed
#
# GCVI_filled_2008087.tif
# image87 completed
#
# GCVI_filled_2008088.tif
# image88 completed
#
# GCVI_filled_2008089.tif
# image89 completed
#
# GCVI_filled_2008090.tif
# image90 completed
#
# GCVI_filled_2008091.tif
# image91 completed
#
# GCVI_filled_2008092.tif
# image92 completed
#
# GCVI_filled_2008093.tif
# image93 completed
#
# GCVI_filled_2008094.tif
# image94 completed
#
# GCVI_filled_2008095.tif
# image95 completed
#
# GCVI_filled_2008096.tif
# image96 completed
#
# GCVI_filled_2008097.tif
# image97 completed
#
# GCVI_filled_2008098.tif
# image98 completed
#
# GCVI_filled_2008099.tif
# image99 completed
#
# GCVI_filled_2008100.tif
# image100 completed
#
# GCVI_filled_2008101.tif
# image101 completed
#
# GCVI_filled_2008102.tif
# image102 completed
#
# GCVI_filled_2008103.tif
# image103 completed
#
# GCVI_filled_2008104.tif
# image104 completed
#
# GCVI_filled_2008105.tif
# image105 completed
#
# GCVI_filled_2008106.tif
# image106 completed
#
# GCVI_filled_2008107.tif
# image107 completed
#
# GCVI_filled_2008108.tif
# image108 completed
#
# GCVI_filled_2008109.tif
# image109 completed
#
# GCVI_filled_2008110.tif
# image110 completed
#
# GCVI_filled_2008111.tif
# image111 completed
#
# GCVI_filled_2008112.tif
# image112 completed
#
# GCVI_filled_2008113.tif
# image113 completed
#
# GCVI_filled_2008114.tif
# image114 completed
#
# GCVI_filled_2008115.tif
# image115 completed
#
# GCVI_filled_2008116.tif
# image116 completed
#
# GCVI_filled_2008117.tif
# image117 completed
#
# GCVI_filled_2008118.tif
# image118 completed
#
# GCVI_filled_2008119.tif
# image119 completed
#
# GCVI_filled_2008120.tif
# image120 completed
#
# GCVI_filled_2008121.tif
# image121 completed
#
# GCVI_filled_2008122.tif
# image122 completed
#
# GCVI_filled_2008123.tif
# image123 completed
#
# GCVI_filled_2008124.tif
# image124 completed
#
# GCVI_filled_2008125.tif
# image125 completed
#
# GCVI_filled_2008126.tif
# image126 completed
#
# GCVI_filled_2008127.tif
# image127 completed
#
# GCVI_filled_2008128.tif
# image128 completed
#
# GCVI_filled_2008129.tif
# image129 completed
#
# GCVI_filled_2008130.tif
# image130 completed
#
# GCVI_filled_2008131.tif
# image131 completed
#
# GCVI_filled_2008132.tif
# image132 completed
#
# GCVI_filled_2008133.tif
# image133 completed
#
# GCVI_filled_2008134.tif
# image134 completed
#
# GCVI_filled_2008135.tif
# image135 completed
#
# GCVI_filled_2008136.tif
# image136 completed
#
# GCVI_filled_2008137.tif
# image137 completed
#
# GCVI_filled_2008138.tif
# image138 completed
#
# GCVI_filled_2008139.tif
# image139 completed
#
# GCVI_filled_2008140.tif
# image140 completed
#
# GCVI_filled_2008141.tif
# image141 completed
#
# GCVI_filled_2008142.tif
# image142 completed
#
# GCVI_filled_2008143.tif
# image143 completed
#
# GCVI_filled_2008144.tif
# image144 completed
#
# GCVI_filled_2008145.tif
# image145 completed
#
# GCVI_filled_2008146.tif
# image146 completed
#
# GCVI_filled_2008147.tif
# image147 completed
#
# GCVI_filled_2008148.tif
# image148 completed
#
# GCVI_filled_2008149.tif
# image149 completed
#
# GCVI_filled_2008150.tif
# image150 completed
#
# GCVI_filled_2008151.tif
# image151 completed
#
# GCVI_filled_2008152.tif
# image152 completed
#
# GCVI_filled_2008153.tif
# image153 completed
#
# GCVI_filled_2008154.tif
# image154 completed
#
# GCVI_filled_2008155.tif
# image155 completed
#
# GCVI_filled_2008156.tif
# image156 completed
#
# GCVI_filled_2008157.tif
# image157 completed
#
# GCVI_filled_2008158.tif
# image158 completed
#
# GCVI_filled_2008159.tif
# image159 completed
#
# GCVI_filled_2008160.tif
# image160 completed
#
# GCVI_filled_2008161.tif
# image161 completed
#
# GCVI_filled_2008162.tif
# image162 completed
#
# GCVI_filled_2008163.tif
# image163 completed
#
# GCVI_filled_2008164.tif
# image164 completed
#
# GCVI_filled_2008165.tif
# image165 completed
#
# GCVI_filled_2008166.tif
# image166 completed
#
# GCVI_filled_2008167.tif
# image167 completed
#
# GCVI_filled_2008168.tif
# image168 completed
#
# GCVI_filled_2008169.tif
# image169 completed
#
# GCVI_filled_2008170.tif
# image170 completed
#
# GCVI_filled_2008171.tif
# image171 completed
#
# GCVI_filled_2008172.tif
# image172 completed
#
# GCVI_filled_2008173.tif
# image173 completed
#
# GCVI_filled_2008174.tif
# image174 completed
#
# GCVI_filled_2008175.tif
# image175 completed
#
# GCVI_filled_2008176.tif
# image176 completed
#
# GCVI_filled_2008177.tif
# image177 completed
#
# GCVI_filled_2008178.tif
# image178 completed
#
# GCVI_filled_2008179.tif
# image179 completed
#
# GCVI_filled_2008180.tif
# image180 completed
#
# GCVI_filled_2008181.tif
# image181 completed
#
# GCVI_filled_2008182.tif
# image182 completed
#
# GCVI_filled_2008183.tif
# image183 completed
#
# GCVI_filled_2008184.tif
# image184 completed
#
# GCVI_filled_2008185.tif
# image185 completed
# GCVI_filled_2008186.tif
# image186 completed
#
# GCVI_filled_2008187.tif
# image187 completed
#
# GCVI_filled_2008188.tif
# image188 completed
#
# GCVI_filled_2008189.tif
# image189 completed
#
# GCVI_filled_2008190.tif
# image190 completed
#
# GCVI_filled_2008191.tif
# image191 completed
#
# GCVI_filled_2008192.tif
# image192 completed
#
# GCVI_filled_2008193.tif
# image193 completed
#
# GCVI_filled_2008194.tif
# image194 completed
#
# GCVI_filled_2008195.tif
# image195 completed
#
# GCVI_filled_2008196.tif
# image196 completed
#
# GCVI_filled_2008197.tif
# image197 completed
#
# GCVI_filled_2008198.tif
# image198 completed
#
# GCVI_filled_2008199.tif
# image199 completed
#
# GCVI_filled_2008200.tif
# image200 completed
#
# GCVI_filled_2008201.tif
# image201 completed
#
# GCVI_filled_2008202.tif
# image202 completed
#
# GCVI_filled_2008203.tif
# image203 completed
#
# GCVI_filled_2008204.tif
# image204 completed
#
# GCVI_filled_2008205.tif
# image205 completed
#
# GCVI_filled_2008206.tif
# image206 completed
#
# GCVI_filled_2008207.tif
# image207 completed
#
# GCVI_filled_2008208.tif
# image208 completed
#
# GCVI_filled_2008209.tif
# image209 completed
#
# GCVI_filled_2008210.tif
# image210 completed
#
# GCVI_filled_2008211.tif
# image211 completed
#
# GCVI_filled_2008212.tif
# image212 completed
#
# GCVI_filled_2008213.tif
# image213 completed
#
# GCVI_filled_2008214.tif
# image214 completed
#
# GCVI_filled_2008215.tif
# image215 completed
#
# GCVI_filled_2008216.tif
# image216 completed
#
# GCVI_filled_2008217.tif
# image217 completed
#
# GCVI_filled_2008218.tif
# image218 completed
#
# GCVI_filled_2008219.tif
# image219 completed
#
# GCVI_filled_2008220.tif
# image220 completed
#
# GCVI_filled_2008221.tif
# image221 completed
#
# GCVI_filled_2008222.tif
# image222 completed
#
# GCVI_filled_2008223.tif
# image223 completed
#
# GCVI_filled_2008224.tif
# image224 completed
#
# GCVI_filled_2008225.tif
# image225 completed
#
# GCVI_filled_2008226.tif
# image226 completed
#
# GCVI_filled_2008227.tif
# image227 completed
#
# GCVI_filled_2008228.tif
# image228 completed
#
# GCVI_filled_2008229.tif
# image229 completed
#
# GCVI_filled_2008230.tif
# image230 completed
#
# GCVI_filled_2008231.tif
# image231 completed
#
# GCVI_filled_2008232.tif
# image232 completed
#
# GCVI_filled_2008233.tif
# image233 completed
#
# GCVI_filled_2008234.tif
# image234 completed
#
# GCVI_filled_2008235.tif
# image235 completed
#
# GCVI_filled_2008236.tif
# image236 completed
#
# GCVI_filled_2008237.tif
# image237 completed
#
# GCVI_filled_2008238.tif
# image238 completed
#
# GCVI_filled_2008239.tif
# image239 completed
#
# GCVI_filled_2008240.tif
# image240 completed
#
# GCVI_filled_2008241.tif
# image241 completed
#
# GCVI_filled_2008242.tif
# image242 completed
#
# GCVI_filled_2008243.tif
# image243 completed
#
# GCVI_filled_2008244.tif
# image244 completed
#
# GCVI_filled_2008245.tif
# image245 completed
#
# GCVI_filled_2008246.tif
# image246 completed
#
# GCVI_filled_2008247.tif
# image247 completed
#
# GCVI_filled_2008248.tif
# image248 completed
#
# GCVI_filled_2008249.tif
# image249 completed
#
# GCVI_filled_2008250.tif
# image250 completed
#
# GCVI_filled_2008251.tif
# image251 completed
#
# GCVI_filled_2008252.tif
# image252 completed
#
# GCVI_filled_2008253.tif
# image253 completed
#
# GCVI_filled_2008254.tif
# image254 completed
#
# GCVI_filled_2008255.tif
# image255 completed
#
# GCVI_filled_2008256.tif
# image256 completed
#
# GCVI_filled_2008257.tif
# image257 completed
#
# GCVI_filled_2008258.tif
# image258 completed
#
# GCVI_filled_2008259.tif
# image259 completed
#
# GCVI_filled_2008260.tif
# image260 completed
#
# GCVI_filled_2008261.tif
# image261 completed
#
# GCVI_filled_2008262.tif
# image262 completed
#
# GCVI_filled_2008263.tif
# image263 completed
#
# GCVI_filled_2008264.tif
# image264 completed
#
# GCVI_filled_2008265.tif
# image265 completed
#
# GCVI_filled_2008266.tif
# image266 completed
#
# GCVI_filled_2008267.tif
# image267 completed
#
# GCVI_filled_2008268.tif
# image268 completed
#
# GCVI_filled_2008269.tif
# image269 completed
#
# GCVI_filled_2008270.tif
# image270 completed
#
# GCVI_filled_2008271.tif
# image271 completed
#
# GCVI_filled_2008272.tif
# image272 completed
#
# GCVI_filled_2008273.tif
# image273 completed
#
# GCVI_filled_2008274.tif
# image274 completed
#
# GCVI_filled_2008275.tif
# image275 completed
#
# GCVI_filled_2008276.tif
# image276 completed
#
# GCVI_filled_2008277.tif
# image277 completed
#
# GCVI_filled_2008278.tif
# image278 completed
#
# GCVI_filled_2008279.tif
# image279 completed
#
# GCVI_filled_2008280.tif
# image280 completed
#
# GCVI_filled_2008281.tif
# image281 completed
#
# GCVI_filled_2008282.tif
# image282 completed
#
# GCVI_filled_2008283.tif
# image283 completed
#
# GCVI_filled_2008284.tif
# image284 completed
#
# GCVI_filled_2008285.tif
# image285 completed
#
# GCVI_filled_2008286.tif
# image286 completed
#
# GCVI_filled_2008287.tif
# image287 completed
#
# GCVI_filled_2008288.tif
# image288 completed
#
# GCVI_filled_2008289.tif
# image289 completed
#
# GCVI_filled_2008290.tif
# image290 completed
#
# GCVI_filled_2008291.tif
# image291 completed
#
# GCVI_filled_2008292.tif
# image292 completed
#
# GCVI_filled_2008293.tif
# image293 completed
#
# GCVI_filled_2008294.tif
# image294 completed
#
# GCVI_filled_2008295.tif
# image295 completed
#
# GCVI_filled_2008296.tif
# image296 completed
#
# GCVI_filled_2008297.tif
# image297 completed
#
# GCVI_filled_2008298.tif
# image298 completed
#
# GCVI_filled_2008299.tif
# image299 completed
#
# GCVI_filled_2008300.tif
# image300 completed
#
# GCVI_filled_2008301.tif
# image301 completed
#
# GCVI_filled_2008302.tif
# image302 completed
#
# GCVI_filled_2008303.tif
# image303 completed
#
# GCVI_filled_2008304.tif
# image304 completed
#
# GCVI_filled_2008305.tif
# image305 completed
#
# GCVI_filled_2008306.tif
# image306 completed
#
# GCVI_filled_2008307.tif
# image307 completed
#
# GCVI_filled_2008308.tif
# image308 completed
#
# GCVI_filled_2008309.tif
# image309 completed
#
# GCVI_filled_2008310.tif
# image310 completed
#
# GCVI_filled_2008311.tif
# image311 completed
#
# GCVI_filled_2008312.tif
# image312 completed
#
# GCVI_filled_2008313.tif
# image313 completed
#
# GCVI_filled_2008314.tif
# image314 completed
#
# GCVI_filled_2008315.tif
# image315 completed
#
# GCVI_filled_2008316.tif
# image316 completed
#
# GCVI_filled_2008317.tif
# image317 completed
#
# GCVI_filled_2008318.tif
# image318 completed
#
# GCVI_filled_2008319.tif
# image319 completed
#
# GCVI_filled_2008320.tif
# image320 completed
#
# GCVI_filled_2008321.tif
# image321 completed
#
# GCVI_filled_2008322.tif
# image322 completed
#
# GCVI_filled_2008323.tif
# image323 completed
#
# GCVI_filled_2008324.tif
# image324 completed
#
# GCVI_filled_2008325.tif
# image325 completed
#
# GCVI_filled_2008326.tif
# image326 completed
#
# GCVI_filled_2008327.tif
# image327 completed
#
# GCVI_filled_2008328.tif
# image328 completed
#
# GCVI_filled_2008329.tif
# image329 completed
#
# GCVI_filled_2008330.tif
# image330 completed
#
# GCVI_filled_2008331.tif
# image331 completed
#
# GCVI_filled_2008332.tif
# image332 completed
#
# GCVI_filled_2008333.tif
# image333 completed
#
# GCVI_filled_2008334.tif
# image334 completed
#
# GCVI_filled_2008335.tif
# image335 completed
#
# GCVI_filled_2008336.tif
# image336 completed
#
# GCVI_filled_2008337.tif
# image337 completed
#
# GCVI_filled_2008338.tif
# image338 completed
#
# GCVI_filled_2008339.tif
# image339 completed
#
# GCVI_filled_2008340.tif
# image340 completed
#
# GCVI_filled_2008341.tif
# image341 completed
#
# GCVI_filled_2008342.tif
# image342 completed
#
# GCVI_filled_2008343.tif
# image343 completed
#
# GCVI_filled_2008344.tif
# image344 completed
#
# GCVI_filled_2008345.tif
# image345 completed
#
# GCVI_filled_2008346.tif
# image346 completed
#
# GCVI_filled_2008347.tif
# image347 completed
#
# GCVI_filled_2008348.tif
# image348 completed
#
# GCVI_filled_2008349.tif
# image349 completed
#
# GCVI_filled_2008350.tif
# image350 completed
#
# GCVI_filled_2008351.tif
# image351 completed
#
# GCVI_filled_2008352.tif
# image352 completed
#
# GCVI_filled_2008353.tif
# image353 completed
#
# GCVI_filled_2008354.tif
# image354 completed
#
# GCVI_filled_2008355.tif
# image355 completed
#
# GCVI_filled_2008356.tif
# image356 completed
#
# GCVI_filled_2008357.tif
# image357 completed
#
# GCVI_filled_2008358.tif
# image358 completed
#
# GCVI_filled_2008359.tif
# image359 completed
#
# GCVI_filled_2008360.tif
# image360 completed
#
# GCVI_filled_2008361.tif
# image361 completed
#
# GCVI_filled_2008362.tif
# image362 completed
#
# GCVI_filled_2008363.tif
# image363 completed
#
# GCVI_filled_2008364.tif
# image364 completed
#
# GCVI_filled_2008365.tif
# image365 completed
#
# GCVI_filled_2008366.tif
# image366 completed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-f9ef1b2ff774> in <module>()
#      12     print("image"+str(index)+" completed \n")
#      13
# ---> 14 print("There are a total of " + len(All_GCVI) + "gcvi images")
#
# TypeError: must be str, not int

# %%
#Concatenate dictionaries obtained from each image
from collections import defaultdict
dict_list = list(All_GCVI.values())
output = defaultdict(list)

for d in dict_list:
    for key, value in d.items():
        output[key].append(value)

#Save the data as csv file
os.chdir('/home/heisenberg/my_repo/Data/Output')
final = pd.DataFrame.from_dict(output)
final.to_csv('2008.csv',index=False)

# %%
#Read the saved data from csv file and optimize
os.chdir('/home/heisenberg/my_repo/Data/Output')
data = pd.read_csv('2008.csv', index_col=0)
gcvi_values = np.asarray(data.iloc[:,0])
length = len(gcvi_values)

# %%
#Start optimization process
def sigmoid(t):
    return 1 / (1 + np.exp(-t))


def Cost_a(x):
    def a_logistic(x,t):
        return Lmin_1 + dL_1 * sigmoid(-(x[0] - x[1] * t))
    time = np.arange(1,np.argmax(gcvi_values)+1)
    cost = 0
    for i in time:
        out = a_logistic(x,i)
        cost += (out - gcvi_values[i-1]) * (out - gcvi_values[i-1])
    return cost

def Cost_b(x):
    def b_logistic(x,t):
        return Lmin_2 + dL_2 * sigmoid(-(-x[0] + x[1]*(t - t12)))
    time = np.arange(np.argmax(gcvi_values)+1,length)
    cost = 0
    for i in time:
        out = b_logistic(x,i)
        cost += (out - gcvi_values[i-1]) * (out - gcvi_values[i-1])
    return cost


def Cost(x):
    def double_logistic(x,t):
        if t <= x[4]:
            return x[5] + x[7] * sigmoid(-(x[0] - x[1] * t))
        else:
            return x[6] + x[8] * sigmoid(-(-x[2] + x[3]*(t - x[4])))
    time = np.arange(1,length)
    cost = 0
    for i in time:
        out = double_logistic(x,i)
        cost += (out - gcvi_values[i-1]) * (out - gcvi_values[i-1])
    return cost

def double_logistic_plot(x,t):
    if t <= x[4]:
        return x[5] + x[7] * sigmoid(-(x[0] - x[1] * t))
    else:
        return x[6] + x[8] * sigmoid(-(-x[2] + x[3]*(t - x[4])))

    
num_of_county = len(county_FIPS)
predicted_by_county = []

for county in np.arange(num_of_county):
    gcvi_values = np.asarray(data.iloc[:,county])
    length = len(gcvi_values)
    
    Lmin_1 = gcvi_values[0]
    Lmin_2 = gcvi_values[-1]
    x = (0,0)
    dL_1 = gcvi_values.max() - Lmin_1
    y = (0,0)
    dL_2 = gcvi_values.max() - Lmin_2
    t12 = np.argmax(gcvi_values)


    res_1 = optimize.minimize(Cost_a, x, method='Nelder-Mead')
    res_2 = optimize.minimize(Cost_b, y, method='Nelder-Mead')

    z = np.zeros(9)
    z[4] = np.argmax(gcvi_values) + 1
    z[5] = Lmin_1
    z[6] = Lmin_2
    z[7] = gcvi_values.max() - Lmin_1
    z[8] = gcvi_values.max() - Lmin_2
    z[0] = res_1.x[0]
    z[1] = res_1.x[1]
    z[2] = res_2.x[0]
    z[3] = res_2.x[1]


    eq_cons = {'type': 'eq', 'fun' : lambda x: [x[7] * np.exp(x[2]) - x[8] * np.exp(x[1] * x[4] - x[0]) + x[7] - x[8]],'jac' : lambda x: np.array([x[8] * np.exp(x[1] * x[4] - x[0]), x[4] *-x[8] * np.exp(x[1] * x[4] - x[0]),x[7] * np.exp(x[2]), 0,x[1] *-x[8] * np.exp(x[1] * x[4] - x[0]),0,0,np.exp(x[2])+1,-1-np.exp(x[1] * x[4] - x[0])])}

    eq_cons_1 = {'type': 'eq', 'fun' : lambda x: x[7] + x[5] - x[8] - x[6],'jac' : lambda x: np.array([0,0,0,0,0,1,-1,1,-1])}

    res = optimize.minimize(Cost, z, method='SLSQP', jac = '2-point',constraints=(eq_cons,eq_cons_1),options={'maxiter':200})

    params = res.x
    days = np.arange(length)
    y = []
    for day in days:
        y.append(double_logistic_plot(params,day))

    y = np.asarray(y)
    predicted_by_county.append(np.argmax(y>1.2*y[0]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-ec3f0153a888> in <module>()
#      49
#      50 for county in np.arange(num_of_county):
# ---> 51     gcvi_values = np.asarray(data.iloc[:,county])
#      52     length = len(gcvi_values)
#      53
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2011     def _getitem_tuple(self, tup):
#    2012
# -> 2013         self._has_valid_tuple(tup)
#    2014         try:
#    2015             return self._getitem_lowerdim(tup)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     220                 raise IndexingError('Too many indexers')
#     221             try:
# --> 222                 self._validate_key(k, i)
#     223             except ValueError:
#     224                 raise ValueError("Location based indexing can only have "
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1955             return
#    1956         elif is_integer(key):
# -> 1957             self._validate_integer(key, axis)
#    1958         elif isinstance(key, tuple):
#    1959             # a tuple should already have been caught by this point
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
#Plot the predicted sow date to ground truth values for each year
counties = np.arange(num_of_county)
predicted_by_county = np.asarray(predicted_by_county)
sow_date = np.asarray(sow_date)
pred, = plt.plot(counties, predicted_by_county, label='Predicted')
truth, = plt.plot(counties, sow_date, label='Ground Truth')
plt.legend(handles=[pred, truth])
plt.title('Predicted Sow Date vs. Actual Sow Date')
plt.xlabel('County')
plt.ylabel('Sow Day')
# Out:
# Text(0, 0.5, 'Sow Day')
